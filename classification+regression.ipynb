# %%
! pip install transformers
! pip install datasets
# !pip install torchmetrics
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import f1_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 7.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 85.5 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 51.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.21.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 8.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 77.1 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.9.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 59.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 95.8 MB/s
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.4.0 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 8.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.12.1+cu113)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.9.3

# %%
from transformers import AutoTokenizer, AutoModel, AdamW
from collections import defaultdict
from transformers import get_linear_schedule_with_warmup
import time

from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics import accuracy_score

# %%
from sklearn.utils import shuffle
import numpy as np

from sklearn.metrics import f1_score
import datasets
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd
from transformers import BertModel, BertTokenizer
from numpy import *
from torch import nn, optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/新建文件夹/ERAI Dataset_with_translation
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/新建文件夹/ERAI Dataset_with_translation

# %%
pd.set_option('display.max_rows', None)

# %%
df_unsupervised = pd.read_json('/content/drive/MyDrive/新建文件夹/ERAI_Dataset_unsupervised.json')

# %%
df = pd.read_json('ERAI_Dataset_pairwise_train_with_translation.json')
# df2 = pd.read_json('ERAI_Dataset_pairwise_test.json')
df.reset_index(drop = True,inplace = True)
df = df.dropna(axis = 0)



df['post1_en']=df['post1_en'].apply(lambda x:x.replace('\n',''))
df['post2_en']=df['post2_en'].apply(lambda x:x.replace('\n',''))

# %%
df

# %%
PRETRAINED_MODEL_NAME = 'yiyanghkust/finbert-tone'
# 获取预测模型所使用的tokenizer

#"nlpaueb/sec-bert-shape"
tokenizer = AutoTokenizer.from_pretrained(PRETRAINED_MODEL_NAME)

# %%
def generate_input_data(post1,post2,mpp_label,ml_label,max_len,mpp_value1,ml_value1,mpp_value2,ml_value2):
  
  
  first_all_value = pd.concat([mpp_value1,ml_value1],axis=1)
  second_all_value = pd.concat([mpp_value2,ml_value2],axis=1)
  full_text = []
  attention_mask = []
  token_type_ids = []
  first_length = []
  second_length = []
  for i,j in zip(post1,post2):
    if len(i)>max_len:
      i = i[:max_len]
    if len(j)>max_len:
      j = j[:max_len]
    
    i = tokenizer.tokenize(i)
    j = tokenizer.tokenize(j)

    first_length.append(len(i))
    second_length.append(len(j))
    
    text = ['[CLS]']+i+['[SEP]']+j+['[SEP]']
    full_text.append(tokenizer.convert_tokens_to_ids(text))
    attention_mask.append(np.ones_like(text))

    token_type_id = [0]*(len(i)+2) + [1]*(len(j)+1)
    token_type_ids.append(token_type_id)

  all_pad_tokens = pad_sequences(full_text, maxlen=max_len*2, padding='post', truncating='post')
  all_mask = pad_sequences(attention_mask, maxlen=max_len*2, padding='post', truncating='post')
  token_type_ids = pad_sequences(token_type_ids, maxlen=max_len*2, padding='post', truncating='post')
  
  return {
      'input_ids': torch.tensor(all_pad_tokens,dtype=torch.long),
      'attention_mask': torch.tensor(all_mask, dtype=torch.long),
      'token_type_ids':torch.tensor(token_type_ids,dtype = torch.long),
      'mpp_label':torch.tensor(mpp_label.values,dtype = torch.long),
      'ml_label':torch.tensor(ml_label.values,dtype = torch.long),
      'first_all_value': torch.tensor(first_all_value.values, dtype=torch.float),
      'second_all_value': torch.tensor(second_all_value.values, dtype=torch.float),
      'first_sen_len':torch.tensor(first_length,dtype = torch.long),
      'second_sen_len':torch.tensor(second_length,dtype = torch.long)
      
  }

# %%
class BertNerClassifier(nn.Module):

  def __init__(self, n_classes_cls,n_classes_reg):
    super(BertNerClassifier, self).__init__()
    self.bert = AutoModel.from_pretrained('yiyanghkust/finbert-tone')
    self.drop = nn.Dropout(p=0.1)
    self.out_cls = nn.Linear(self.bert.config.hidden_size, n_classes_cls)

    self.out_reg = nn.Linear(self.bert.config.hidden_size, n_classes_reg)
    self.sigmoid = nn.Sigmoid()

  
  def forward(self, input_ids, attention_mask,token_type_ids,max_len,length1,length2):
    output = self.bert(
      input_ids=input_ids,
      attention_mask=attention_mask,
      token_type_ids = token_type_ids

    )
    
    output = self.drop(output[0])
    
    cls_info = output[0][0]
    sent1_info = torch.mean(output[0][1:(length1+1)],dim=0)
    sent2_info = torch.mean(output[0][length1+2:(length1+2+length2)],dim=0)
    
    # output = torch.cat((cls_info,sent1_info,sent2_info),dim = 0)
    cls_info = self.out_cls(cls_info)
    
    
    
    return self.sigmoid(cls_info),self.out_reg(sent1_info),self.out_reg(sent2_info)

# %%
 
class DataSequence(Dataset):

    def __init__(self, data):

      self.features = data['input_ids']
      self.mask = data['attention_mask']
      self.token_type_ids = data['token_type_ids']
      self.mpp_label = data['mpp_label']
      self.ml_label = data['ml_label']
      self.first_all_value = data['first_all_value']
      self.second_all_value = data['second_all_value']
      self.first_sen_len = data['first_sen_len']   
      self.second_sen_len = data['second_sen_len']   

    def __len__(self):

        return len(self.mpp_label)

    def __getitem__(self, index):

        return self.features[index],self.mask[index],self.token_type_ids[index],self.mpp_label[index],self.ml_label[index],self.first_all_value[index],self.second_all_value[index],self.first_sen_len[index],self.second_sen_len[index]

# %%
def generate_dataloader(post1,post2,mpp_label,ml_label,max_len,mpp_value1,ml_value1,mpp_value2,ml_value2,batch_size):
  data = generate_input_data(post1,post2,mpp_label,ml_label,max_len,mpp_value1,ml_value1,mpp_value2,ml_value2)
  data = DataSequence(data)
  dataloader = DataLoader(data, num_workers=10, batch_size=batch_size)
  
  return dataloader

# %%
EPOCHS = 50

# total_steps = len(train_data_loader) * EPOCHS

# scheduler = get_linear_schedule_with_warmup(
#   optimizer,
#   num_warmup_steps=0,
#   num_training_steps=total_steps
# )
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
loss_reg = nn.MSELoss().to(device)
loss_cls = nn.BCELoss().to(device)

# %%
def train_and_eval(model, 
  train_loader, 
  validation_loader, 
  optimizer,  
  device,
  epoch,
  # label_num 
  ):
  model.train()
  max_len = 256
  mpp_accuracy_state = 0
  ml_accuracy_state = 0
  for epo in range(epoch):
    
    train_loss = []
    
    global train_mpp_predictions 
    train_mpp_predictions = []
    global train_ml_predictions
    train_ml_predictions = []
    

    validation_loss = []
    
    validation_mpp_predictions = []
    validation_ml_predictions = []


    global real_train_mpp 
    real_train_mpp = []
    global real_train_ml
    real_train_ml = []
    real_validation_mpp = []
    real_validation_ml = []
    
   
    
    for data in train_loader:
      
      input_ids = data[0].to(device)
      attention_mask = data[1].to(device)
      token_type_ids = data[2].to(device)
      
      mpp_targets = data[3].to(device)
      ml_targets = data[4].to(device)
      first_targets = data[5].to(device)
      second_targets = data[6].to(device)
      first_sen_len = data[7].to(device)
      second_sen_len = data[8].to(device)
      
      

      output_cls,output_sen1,ouptut_sen2 = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids = token_type_ids,
        max_len = max_len,
        length1 = first_sen_len,
        length2 = second_sen_len
   
      )
      
      
      
      loss1 = loss_cls(output_cls.view(-1),torch.tensor([mpp_targets,ml_targets],dtype = torch.float).to(device))
      
      loss2 = loss_reg(output_sen1,first_targets.view(-1))
      
      loss3 = loss_reg(ouptut_sen2,second_targets.view(-1))
      
      loss = loss1
 
      
      

      train_loss.append(loss.item())
      
      
      
      if output_cls[0]>0.5:
        train_mpp_predictions.append(1)
      else:
        train_mpp_predictions.append(0)
      if output_cls[1]>0.5:
        train_ml_predictions.append(1)
      else:
        train_ml_predictions.append(0)

      real_train_mpp.append(mpp_targets.cpu().item())
      real_train_ml.append(ml_targets.cpu().item())
    
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    model.eval()

    with torch.no_grad():
      for data in validation_loader:
    
        input_ids = data[0].to(device)
        attention_mask = data[1].to(device)
        token_type_ids = data[2].to(device)
      
        mpp_targets = data[3].to(device)
        ml_targets = data[4].to(device)
        first_targets = data[5].to(device)
        second_targets = data[6].to(device)
        first_sen_len = data[7].to(device)
        second_sen_len = data[8].to(device)
      

        output_cls,output_sen1,ouptut_sen2 = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids = token_type_ids,
        max_len = max_len,
        length1 = first_sen_len,
        length2 = second_sen_len
   
        )
        loss1 = loss_cls(output_cls,torch.tensor([mpp_targets,ml_targets],dtype = torch.float).to(device))
        
        # loss2 = loss_reg(output_sen1,first_targets.view(-1))
        
        # loss3 = loss_reg(ouptut_sen2,second_targets.view(-1))
        
        loss = loss1
 
      
      

        validation_loss.append(loss.item())
      
        if output_cls[0]>0.5:
          validation_mpp_predictions.append(1)
        else:
          validation_mpp_predictions.append(0)
        if output_cls[1]>0.5:
          validation_ml_predictions.append(1)
        else:
          validation_ml_predictions.append(0)
       

        real_validation_mpp.append(mpp_targets.cpu().item())
        real_validation_ml.append(ml_targets.cpu().item())
    
    train_mpp_accuracy = accuracy_score(real_train_mpp, train_mpp_predictions)
    train_ml_accuracy = accuracy_score(real_train_ml, train_ml_predictions)
    validation_mpp_accuracy = accuracy_score(real_validation_mpp, validation_mpp_predictions)
    validation_ml_accuracy = accuracy_score(real_validation_ml, validation_ml_predictions)
    
    final_train_loss = np.mean(train_loss)
 
    final_validation_loss = np.mean(validation_loss)


    print(
'Epoch [{}] Train Totol Loss: {:.4f}, Train MPP Accuracy: {:.4f}, Train ML Accuracy: {:.4f}, Valid Total Loss: {:.4f}, Valid MPP Accuracy: {:.4f}, Valid ML Accuracy: {:.4f}'
    .format(epo+1,final_train_loss, train_mpp_accuracy, train_ml_accuracy,final_validation_loss,validation_mpp_accuracy,validation_ml_accuracy))

# %%
random_seed = [171,354,550,667,985]
for i in random_seed:
  
  df = shuffle(df,random_state=i)

  
  train = df[0:156]

  test = df[156:200]

  train_post1 = train['post1_en']
  train_post2 = train['post2_en']
  train_mpp_label = train['MPP_label']
  train_ml_label = train['ML_label']
  train_mpp_value1 = train['MPP1'] 
  train_mpp_value2 = train['MPP2']
  train_ml_value1 = train['ML1']
  train_ml_value2 = train['ML2']

  test_post1 = test['post1_en']
  test_post2 = test['post2_en']
  test_mpp_label = test['MPP_label']
  test_ml_label = test['ML_label']
  test_mpp_value1 = test['MPP1'] 
  test_mpp_value2 = test['MPP2']
  test_ml_value1 = test['ML1']
  test_ml_value2 = test['ML2']

  max_len = 256
  batch_size = 1
  train_dataloader = generate_dataloader(train_post1,train_post2,train_mpp_label,train_ml_label,max_len,train_mpp_value1,train_ml_value1,train_mpp_value2,train_ml_value2,batch_size)
  test_dataloader = generate_dataloader(test_post1,test_post2,test_mpp_label,test_ml_label,max_len,test_mpp_value1,test_ml_value1,test_mpp_value2,test_ml_value2,batch_size)

  label_num_cls = 2
  label_num_reg = 2
  model= BertNerClassifier(label_num_cls,label_num_reg).to(device)
  optimizer = AdamW(model.parameters(), lr=2e-6, correct_bias=False)
  
  
  train_and_eval(model, 
    train_dataloader, 
    test_dataloader, 
    optimizer,  
    device,
    EPOCHS,
    )
# Out:
# Some weights of the model checkpoint at yiyanghkust/finbert-tone were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 0.7368, Train MPP Accuracy: 0.4615, Train ML Accuracy: 0.5000, Valid Total Loss: 0.7068, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [2] Train Totol Loss: 0.5336, Train MPP Accuracy: 0.8141, Train ML Accuracy: 0.8526, Valid Total Loss: 0.7152, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6500
# Epoch [3] Train Totol Loss: 0.3783, Train MPP Accuracy: 0.9808, Train ML Accuracy: 0.9615, Valid Total Loss: 0.7316, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.7000
# Epoch [4] Train Totol Loss: 0.2457, Train MPP Accuracy: 1.0000, Train ML Accuracy: 0.9936, Valid Total Loss: 0.7553, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6750
# Epoch [5] Train Totol Loss: 0.1511, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.7850, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6750
# Epoch [6] Train Totol Loss: 0.0940, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8179, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6750
# Epoch [7] Train Totol Loss: 0.0624, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8513, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6750
# Epoch [8] Train Totol Loss: 0.0445, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8824, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6750
# Epoch [9] Train Totol Loss: 0.0342, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9086, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6750
# Epoch [10] Train Totol Loss: 0.0249, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9392, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6750
# Epoch [11] Train Totol Loss: 0.0196, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9710, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6500
# Epoch [12] Train Totol Loss: 0.0158, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9997, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6500
# Epoch [13] Train Totol Loss: 0.0129, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0285, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6500
# Epoch [14] Train Totol Loss: 0.0108, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0566, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6500
# Epoch [15] Train Totol Loss: 0.0091, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0844, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6500
# Epoch [16] Train Totol Loss: 0.0077, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1120, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6500
# Epoch [17] Train Totol Loss: 0.0066, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1394, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6500
# Epoch [18] Train Totol Loss: 0.0057, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1665, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6500
# Epoch [19] Train Totol Loss: 0.0050, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1935, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.6500
# Epoch [20] Train Totol Loss: 0.0044, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2204, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.6750
# Epoch [21] Train Totol Loss: 0.0039, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2472, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.6750
# Epoch [22] Train Totol Loss: 0.0034, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2738, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.6750
# Epoch [23] Train Totol Loss: 0.0030, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3005, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [24] Train Totol Loss: 0.0027, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3270, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [25] Train Totol Loss: 0.0024, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3536, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [26] Train Totol Loss: 0.0022, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3801, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [27] Train Totol Loss: 0.0020, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4066, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [28] Train Totol Loss: 0.0018, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4332, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [29] Train Totol Loss: 0.0016, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4597, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [30] Train Totol Loss: 0.0015, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4863, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [31] Train Totol Loss: 0.0013, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5129, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [32] Train Totol Loss: 0.0012, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5395, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [33] Train Totol Loss: 0.0011, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5661, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.7000
# Epoch [34] Train Totol Loss: 0.0010, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5929, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.7000
# Epoch [35] Train Totol Loss: 0.0009, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6196, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.7000
# Epoch [36] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6464, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [37] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6733, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [38] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7002, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [39] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7272, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [40] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7543, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [41] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7814, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [42] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8086, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [43] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8358, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [44] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8631, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [45] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8905, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [46] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9177, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [47] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9456, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [48] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9719, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [49] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0024, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Epoch [50] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0187, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.7000
# Some weights of the model checkpoint at yiyanghkust/finbert-tone were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 0.7287, Train MPP Accuracy: 0.4936, Train ML Accuracy: 0.4551, Valid Total Loss: 0.7200, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.4750
# Epoch [2] Train Totol Loss: 0.5222, Train MPP Accuracy: 0.8397, Train ML Accuracy: 0.8205, Valid Total Loss: 0.7393, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [3] Train Totol Loss: 0.3567, Train MPP Accuracy: 0.9872, Train ML Accuracy: 0.9679, Valid Total Loss: 0.7715, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4250
# Epoch [4] Train Totol Loss: 0.2194, Train MPP Accuracy: 1.0000, Train ML Accuracy: 0.9936, Valid Total Loss: 0.8060, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4000
# Epoch [5] Train Totol Loss: 0.1308, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8433, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4250
# Epoch [6] Train Totol Loss: 0.0816, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8830, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4000
# Epoch [7] Train Totol Loss: 0.0545, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9224, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [8] Train Totol Loss: 0.0386, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9605, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [9] Train Totol Loss: 0.0286, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9972, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4000
# Epoch [10] Train Totol Loss: 0.0220, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0328, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4000
# Epoch [11] Train Totol Loss: 0.0173, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0675, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [12] Train Totol Loss: 0.0140, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1013, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [13] Train Totol Loss: 0.0115, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1344, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [14] Train Totol Loss: 0.0096, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1670, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [15] Train Totol Loss: 0.0081, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1990, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [16] Train Totol Loss: 0.0069, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2305, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [17] Train Totol Loss: 0.0059, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2617, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [18] Train Totol Loss: 0.0051, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2925, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [19] Train Totol Loss: 0.0045, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3230, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [20] Train Totol Loss: 0.0039, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3533, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [21] Train Totol Loss: 0.0034, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3834, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [22] Train Totol Loss: 0.0031, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4133, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [23] Train Totol Loss: 0.0027, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4432, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [24] Train Totol Loss: 0.0024, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4729, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [25] Train Totol Loss: 0.0022, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5026, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [26] Train Totol Loss: 0.0020, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5323, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [27] Train Totol Loss: 0.0018, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5619, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [28] Train Totol Loss: 0.0016, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5916, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [29] Train Totol Loss: 0.0014, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6214, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [30] Train Totol Loss: 0.0013, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6512, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [31] Train Totol Loss: 0.0012, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6810, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [32] Train Totol Loss: 0.0011, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7110, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [33] Train Totol Loss: 0.0010, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7411, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [34] Train Totol Loss: 0.0009, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7713, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [35] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8016, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [36] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8321, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [37] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8627, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [38] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8935, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [39] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9244, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [40] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9555, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [41] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9868, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [42] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0183, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [43] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0500, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [44] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0818, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [45] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1138, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3750
# Epoch [46] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1460, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3500
# Epoch [47] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1784, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3500
# Epoch [48] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2110, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3500
# Epoch [49] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2438, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3250
# Epoch [50] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2767, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3250
# Some weights of the model checkpoint at yiyanghkust/finbert-tone were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 0.7343, Train MPP Accuracy: 0.4936, Train ML Accuracy: 0.5064, Valid Total Loss: 0.7134, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [2] Train Totol Loss: 0.5157, Train MPP Accuracy: 0.8205, Train ML Accuracy: 0.8397, Valid Total Loss: 0.7300, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [3] Train Totol Loss: 0.3531, Train MPP Accuracy: 0.9615, Train ML Accuracy: 0.9679, Valid Total Loss: 0.7613, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [4] Train Totol Loss: 0.2198, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8069, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [5] Train Totol Loss: 0.1316, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8577, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [6] Train Totol Loss: 0.0819, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9116, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [7] Train Totol Loss: 0.0545, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9647, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [8] Train Totol Loss: 0.0386, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0167, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [9] Train Totol Loss: 0.0286, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0663, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.5250
# Epoch [10] Train Totol Loss: 0.0220, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1127, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [11] Train Totol Loss: 0.0174, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1571, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [12] Train Totol Loss: 0.0141, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1987, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [13] Train Totol Loss: 0.0116, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2398, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [14] Train Totol Loss: 0.0097, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2785, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [15] Train Totol Loss: 0.0082, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3170, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [16] Train Totol Loss: 0.0070, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3537, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [17] Train Totol Loss: 0.0060, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3901, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [18] Train Totol Loss: 0.0052, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4255, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [19] Train Totol Loss: 0.0046, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4605, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [20] Train Totol Loss: 0.0040, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4948, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [21] Train Totol Loss: 0.0035, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5287, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [22] Train Totol Loss: 0.0031, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5622, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [23] Train Totol Loss: 0.0028, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5954, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [24] Train Totol Loss: 0.0025, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6283, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [25] Train Totol Loss: 0.0022, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6610, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [26] Train Totol Loss: 0.0020, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6935, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [27] Train Totol Loss: 0.0018, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7258, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [28] Train Totol Loss: 0.0016, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7579, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [29] Train Totol Loss: 0.0015, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7899, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [30] Train Totol Loss: 0.0013, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8218, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [31] Train Totol Loss: 0.0012, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8537, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [32] Train Totol Loss: 0.0011, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8854, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [33] Train Totol Loss: 0.0010, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9172, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [34] Train Totol Loss: 0.0009, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9488, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [35] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9805, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [36] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0121, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [37] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0437, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [38] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0753, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [39] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1069, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [40] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1385, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [41] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1701, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [42] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2017, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [43] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2333, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [44] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2649, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [45] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2965, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [46] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3282, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [47] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3598, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [48] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3914, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [49] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.4230, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [50] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.4547, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Some weights of the model checkpoint at yiyanghkust/finbert-tone were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 0.7301, Train MPP Accuracy: 0.5321, Train ML Accuracy: 0.4487, Valid Total Loss: 0.6801, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [2] Train Totol Loss: 0.5312, Train MPP Accuracy: 0.8077, Train ML Accuracy: 0.8205, Valid Total Loss: 0.6910, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [3] Train Totol Loss: 0.3614, Train MPP Accuracy: 0.9359, Train ML Accuracy: 0.9808, Valid Total Loss: 0.7163, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [4] Train Totol Loss: 0.2227, Train MPP Accuracy: 0.9936, Train ML Accuracy: 1.0000, Valid Total Loss: 0.7550, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5250
# Epoch [5] Train Totol Loss: 0.1347, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8016, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.5250
# Epoch [6] Train Totol Loss: 0.0848, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8541, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5250
# Epoch [7] Train Totol Loss: 0.0568, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9050, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [8] Train Totol Loss: 0.0401, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9507, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.4750
# Epoch [9] Train Totol Loss: 0.0296, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9920, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [10] Train Totol Loss: 0.0226, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0310, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5250
# Epoch [11] Train Totol Loss: 0.0178, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0691, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5250
# Epoch [12] Train Totol Loss: 0.0144, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1066, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5250
# Epoch [13] Train Totol Loss: 0.0118, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1433, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5250
# Epoch [14] Train Totol Loss: 0.0098, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1791, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [15] Train Totol Loss: 0.0083, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2141, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [16] Train Totol Loss: 0.0070, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2482, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [17] Train Totol Loss: 0.0061, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2816, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [18] Train Totol Loss: 0.0052, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3143, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [19] Train Totol Loss: 0.0046, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3465, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [20] Train Totol Loss: 0.0040, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3782, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [21] Train Totol Loss: 0.0035, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4095, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [22] Train Totol Loss: 0.0031, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4404, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [23] Train Totol Loss: 0.0028, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4709, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [24] Train Totol Loss: 0.0025, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5012, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [25] Train Totol Loss: 0.0022, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5312, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [26] Train Totol Loss: 0.0020, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5609, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [27] Train Totol Loss: 0.0018, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5904, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [28] Train Totol Loss: 0.0016, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6197, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [29] Train Totol Loss: 0.0015, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6489, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [30] Train Totol Loss: 0.0013, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6779, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4500
# Epoch [31] Train Totol Loss: 0.0012, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7067, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [32] Train Totol Loss: 0.0011, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7355, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [33] Train Totol Loss: 0.0010, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7641, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [34] Train Totol Loss: 0.0009, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7926, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [35] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8210, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [36] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8494, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [37] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8776, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [38] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9058, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [39] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9340, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [40] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9621, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [41] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9901, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [42] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0180, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [43] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0460, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [44] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0738, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [45] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1016, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [46] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1294, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [47] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1571, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [48] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1847, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [49] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2123, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [50] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2398, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Some weights of the model checkpoint at yiyanghkust/finbert-tone were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 0.7219, Train MPP Accuracy: 0.5128, Train ML Accuracy: 0.4872, Valid Total Loss: 0.7291, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [2] Train Totol Loss: 0.5096, Train MPP Accuracy: 0.7756, Train ML Accuracy: 0.8590, Valid Total Loss: 0.7538, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4750
# Epoch [3] Train Totol Loss: 0.3361, Train MPP Accuracy: 0.9487, Train ML Accuracy: 0.9808, Valid Total Loss: 0.8087, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.4500
# Epoch [4] Train Totol Loss: 0.2037, Train MPP Accuracy: 0.9936, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8840, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.4500
# Epoch [5] Train Totol Loss: 0.1236, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9929, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5250
# Epoch [6] Train Totol Loss: 0.0775, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0650, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5000
# Epoch [7] Train Totol Loss: 0.0541, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1448, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5000
# Epoch [8] Train Totol Loss: 0.0399, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1904, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4250
# Epoch [9] Train Totol Loss: 0.0284, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2606, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4250
# Epoch [10] Train Totol Loss: 0.0212, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3565, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4250
# Epoch [11] Train Totol Loss: 0.0164, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4203, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4000
# Epoch [12] Train Totol Loss: 0.0131, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4804, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4000
# Epoch [13] Train Totol Loss: 0.0107, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5420, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4000
# Epoch [14] Train Totol Loss: 0.0090, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6010, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4000
# Epoch [15] Train Totol Loss: 0.0076, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6580, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4250
# Epoch [16] Train Totol Loss: 0.0064, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7119, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4500
# Epoch [17] Train Totol Loss: 0.0055, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7645, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4500
# Epoch [18] Train Totol Loss: 0.0048, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8151, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4500
# Epoch [19] Train Totol Loss: 0.0042, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8650, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4500
# Epoch [20] Train Totol Loss: 0.0037, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9127, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4500
# Epoch [21] Train Totol Loss: 0.0032, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9607, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4500
# Epoch [22] Train Totol Loss: 0.0029, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0055, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4500
# Epoch [23] Train Totol Loss: 0.0026, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0521, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [24] Train Totol Loss: 0.0023, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0914, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [25] Train Totol Loss: 0.0021, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1332, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [26] Train Totol Loss: 0.0022, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1242, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [27] Train Totol Loss: 0.0026, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0817, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.3750
# Epoch [28] Train Totol Loss: 0.0019, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1040, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4250
# Epoch [29] Train Totol Loss: 0.0014, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1601, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [30] Train Totol Loss: 0.0013, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2134, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [31] Train Totol Loss: 0.0012, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2631, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [32] Train Totol Loss: 0.0011, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3102, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [33] Train Totol Loss: 0.0010, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3555, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [34] Train Totol Loss: 0.0009, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3995, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [35] Train Totol Loss: 0.0008, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.4424, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [36] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.4846, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [37] Train Totol Loss: 0.0007, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.5262, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [38] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.5673, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [39] Train Totol Loss: 0.0006, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.6080, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4500
# Epoch [40] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.6483, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [41] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.6883, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [42] Train Totol Loss: 0.0005, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.7281, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [43] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.7677, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [44] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.8071, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [45] Train Totol Loss: 0.0004, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.8463, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [46] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.8854, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [47] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.9243, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [48] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.9632, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [49] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 3.0020, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [50] Train Totol Loss: 0.0003, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 3.0406, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250

# %%
def test_prediction(model, 
  test_dataloader,  
  optimizer,
  device
  ):
  
  test_mpp_predictions = []
  test_ml_predictions = []
  real_test_mpp = []
  real_test_ml= []

  

  model.eval()
  with torch.no_grad():
    for data in test_dataloader:
    
        input_ids = data[0].to(device)
        attention_mask = data[1].to(device)
        token_type_ids = data[2].to(device)
      
        mpp_targets = data[3].to(device)
        ml_targets = data[4].to(device)
        first_targets = data[5].to(device)
        second_targets = data[6].to(device)
        first_sen_len = data[7].to(device)
        second_sen_len = data[8].to(device)
      

        output_cls,output_sen1,ouptut_sen2 = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids = token_type_ids,
        max_len = max_len,
        length1 = first_sen_len,
        length2 = second_sen_len
   
        )
     
        
      
        if output_cls[0]>0.5:
          test_mpp_predictions.append(1)
        else:
          test_mpp_predictions.append(0)
        if output_cls[1]>0.5:
          test_ml_predictions.append(1)
        else:
          test_ml_predictions.append(0)
        # validation_ml_predictions += torch.sum(preds == ml_targets)

        real_test_mpp.append(mpp_targets.cpu().item())
        real_test_ml.append(ml_targets.cpu().item())

        test_mpp_accuracy = accuracy_score(real_test_mpp, test_mpp_predictions)
        test_ml_accuracy = accuracy_score(real_test_ml, test_ml_predictions)

  

  print('Test MMP ACCURACY_SCORE: {:.4f},Test ML ACCURACY_SCORE: {:.4f}'.format(test_mpp_accuracy,test_ml_accuracy))

# %%
test_prediction(model, 
  test_dataloader, 
  optimizer,
  device,
  
  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f1b324ec1ac9> in <module>
# ----> 1 test_prediction(model,
#       2   test_dataloader,
#       3   optimizer,
#       4   device,
#       5
#
# NameError: name 'model' is not defined

# %%
model.load_state_dict(torch.load('fincom_ml_bert_state.bin', map_location=torch.device("cuda:0")))
# Out:
# <All keys matched successfully>

# %%
import googletrans

print(googletrans.LANGUAGES)
from googletrans import Translator
translator = Translator()

# result = Translator.translate('Mikä on nimesi', dest='fr')
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'latin', 'lv': 'latvian', 'lt': 'lithuanian', 'lb': 'luxembourgish', 'mk': 'macedonian', 'mg': 'malagasy', 'ms': 'malay', 'ml': 'malayalam', 'mt': 'maltese', 'mi': 'maori', 'mr': 'marathi', 'mn': 'mongolian', 'my': 'myanmar (burmese)', 'ne': 'nepali', 'no': 'norwegian', 'or': 'odia', 'ps': 'pashto', 'fa': 'persian', 'pl': 'polish', 'pt': 'portuguese', 'pa': 'punjabi', 'ro': 'romanian', 'ru': 'russian', 'sm': 'samoan', 'gd': 'scots gaelic', 'sr': 'serbian', 'st': 'sesotho', 'sn': 'shona', 'sd': 'sindhi', 'si': 'sinhala', 'sk': 'slovak', 'sl': 'slovenian', 'so': 'somali', 'es': 'spanish', 'su': 'sundanese', 'sw': 'swahili', 'sv': 'swedish', 'tg': 'tajik', 'ta': 'tamil', 'te': 'telugu', 'th': 'thai', 'tr': 'turkish', 'uk': 'ukrainian', 'ur': 'urdu', 'ug': 'uyghur', 'uz': 'uzbek', 'vi': 'vietnamese', 'cy': 'welsh', 'xh': 'xhosa', 'yi': 'yiddish', 'yo': 'yoruba', 'zu': 'zulu'}
