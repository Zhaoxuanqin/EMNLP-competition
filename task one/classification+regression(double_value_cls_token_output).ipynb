# %%
! pip install transformers
! pip install datasets
# !pip install torchmetrics
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import f1_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.9.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.7/dist-packages (0.9.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.1.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.12.1+cu113)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)

# %%
from transformers import AutoTokenizer, AutoModel, AdamW
from collections import defaultdict
from transformers import get_linear_schedule_with_warmup
import time

from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics import accuracy_score

# %%
from sklearn.utils import shuffle
import numpy as np

from sklearn.metrics import f1_score
import datasets
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd
from transformers import BertModel, BertTokenizer
from numpy import *
from torch import nn, optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/新建文件夹/ERAI Dataset_with_translation
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/新建文件夹/ERAI Dataset_with_translation

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_json('ERAI_Dataset_pairwise_train_with_translation.json')
df2 = pd.read_json('ERAI_Dataset_pairwise_test_with_translation.json')
df.reset_index(drop = True,inplace = True)
df = df.dropna(axis = 0)



df['post1_en']=df['post1_en'].apply(lambda x:x.replace('\n',''))
df['post2_en']=df['post2_en'].apply(lambda x:x.replace('\n',''))

df['post1']=df['post1'].apply(lambda x:x.replace('\n',''))
df['post2_']=df['post2'].apply(lambda x:x.replace('\n',''))

# %%
PRETRAINED_MODEL_NAME = "bert-base-chinese"
# 获取预测模型所使用的tokenizer

#"nlpaueb/sec-bert-shape"
tokenizer = AutoTokenizer.from_pretrained(PRETRAINED_MODEL_NAME)

# %%
def generate_input_data(post1,post2,mpp_label,ml_label,max_len,mpp_value1,ml_value1,mpp_value2,ml_value2):
  
  
  first_all_value = pd.concat([mpp_value1,ml_value1],axis=1)
  second_all_value = pd.concat([mpp_value2,ml_value2],axis=1)
  full_text = []
  attention_mask = []
  token_type_ids = []
  first_length = []
  second_length = []
  for i,j in zip(post1,post2):
    if len(i)>max_len:
      i = i[:max_len]
    if len(j)>max_len:
      j = j[:max_len]
    
    i = tokenizer.tokenize(i)
    j = tokenizer.tokenize(j)

    first_length.append(len(i))
    second_length.append(len(j))
    
    text = ['[CLS]']+i+['[SEP]']+j+['[SEP]']
    full_text.append(tokenizer.convert_tokens_to_ids(text))
    attention_mask.append(np.ones_like(text))

    token_type_id = [0]*(len(i)+2) + [1]*(len(j)+1)
    token_type_ids.append(token_type_id)

  all_pad_tokens = pad_sequences(full_text, maxlen=max_len*2, padding='post', truncating='post')
  all_mask = pad_sequences(attention_mask, maxlen=max_len*2, padding='post', truncating='post')
  token_type_ids = pad_sequences(token_type_ids, maxlen=max_len*2, padding='post', truncating='post')
  
  return {
      'input_ids': torch.tensor(all_pad_tokens,dtype=torch.long),
      'attention_mask': torch.tensor(all_mask, dtype=torch.long),
      'token_type_ids':torch.tensor(token_type_ids,dtype = torch.long),
      'mpp_label':torch.tensor(mpp_label.values,dtype = torch.float),
      'ml_label':torch.tensor(ml_label.values,dtype = torch.float),
      'first_all_value': torch.tensor(first_all_value.values, dtype=torch.float),
      'second_all_value': torch.tensor(second_all_value.values, dtype=torch.float),
      'first_sen_len':torch.tensor(first_length,dtype = torch.long),
      'second_sen_len':torch.tensor(second_length,dtype = torch.long)
      
  }

# %%
class BertNerClassifier(nn.Module):

  def __init__(self, n_classes_cls,n_classes_reg):
    super(BertNerClassifier, self).__init__()
    self.bert = AutoModel.from_pretrained("bert-base-chinese")
    self.drop = nn.Dropout(p=0.1)
    self.out_cls = nn.Linear(self.bert.config.hidden_size, n_classes_cls)

    self.out_reg = nn.Linear(self.bert.config.hidden_size, n_classes_reg)
    self.sigmoid = nn.Sigmoid()

  
  def forward(self, input_ids, attention_mask,token_type_ids,max_len,length1,length2):
    output = self.bert(
      input_ids=input_ids,
      attention_mask=attention_mask,
      token_type_ids = token_type_ids

    )
    cls_output = []
    sent1_output = []
    sent2_output = []
    
    output = self.drop(output[0])

    for last_output,len1,len2 in zip(output,length1,length2):
      cls_output.append(last_output[0])
      
      sent1_output.append(torch.mean(last_output[1:(len1+1)],dim=0))
      sent2_output.append(torch.mean(last_output[len1+2:(len1+2+len2)],dim=0))

    cls_output = torch.stack(cls_output)
    sent1_output = torch.stack(sent1_output)
    
    sent2_output = torch.stack(sent2_output)
    
    cls_output = self.out_cls(cls_output)
    
    
    
    return self.sigmoid(cls_output),self.out_reg(sent1_output),self.out_reg(sent2_output)

# %%
 
class DataSequence(Dataset):

    def __init__(self, data):

      self.features = data['input_ids']
      self.mask = data['attention_mask']
      self.token_type_ids = data['token_type_ids']
      self.mpp_label = data['mpp_label']
      self.ml_label = data['ml_label']
      self.first_all_value = data['first_all_value']
      self.second_all_value = data['second_all_value']
      self.first_sen_len = data['first_sen_len']   
      self.second_sen_len = data['second_sen_len']   

    def __len__(self):

        return len(self.mpp_label)

    def __getitem__(self, index):

        return self.features[index],self.mask[index],self.token_type_ids[index],self.mpp_label[index],self.ml_label[index],self.first_all_value[index],self.second_all_value[index],self.first_sen_len[index],self.second_sen_len[index]

# %%
def generate_dataloader(post1,post2,mpp_label,ml_label,max_len,mpp_value1,ml_value1,mpp_value2,ml_value2,batch_size):
  data = generate_input_data(post1,post2,mpp_label,ml_label,max_len,mpp_value1,ml_value1,mpp_value2,ml_value2)
  data = DataSequence(data)
  dataloader = DataLoader(data, num_workers=10, batch_size=batch_size)
  
  return dataloader

# %%
EPOCHS = 50


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
loss_reg = nn.MSELoss().to(device)
loss_cls = nn.BCELoss().to(device)

# %%
def train_and_eval(model, 
  train_loader, 
  validation_loader, 
  optimizer,  
  device,
  epoch,
  ):
  model.train()
  max_len = 256
  current_accuracy_state = 0
  for epo in range(epoch):
    
    train_loss = []
    
    global train_mpp_predictions 
    train_mpp_predictions = []
    global train_ml_predictions
    train_ml_predictions = []
    

    validation_loss = []
    
    validation_mpp_predictions = []
    validation_ml_predictions = []


    global real_train_mpp 
    real_train_mpp = []
    global real_train_ml
    real_train_ml = []
    real_validation_mpp = []
    real_validation_ml = []
    
   
    
    for data in train_loader:
      
      input_ids = data[0].to(device)
      attention_mask = data[1].to(device)
      token_type_ids = data[2].to(device)
      
      mpp_targets = data[3].to(device)
      ml_targets = data[4].to(device)
      first_targets = data[5].to(device)
      second_targets = data[6].to(device)
      first_sen_len = data[7].to(device)
      second_sen_len = data[8].to(device)
      
      

      output_cls,output_sen1,ouptut_sen2 = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids = token_type_ids,
        max_len = max_len,
        length1 = first_sen_len,
        length2 = second_sen_len
   
      )
      mpp_ml_label = torch.stack((mpp_targets,ml_targets),1)
      
      
      loss1 = loss_cls(output_cls.view(-1),mpp_ml_label.view(-1)).to(device)
      
      loss2 = loss_reg(output_sen1,first_targets.view(-1))
      
      loss3 = loss_reg(ouptut_sen2,second_targets.view(-1))
      
      loss = loss1+10*loss2+10*loss3
 

      train_loss.append(loss.item())
      
      
      
      for i in output_cls:
        if i[0]>0.5:
          train_mpp_predictions.append(1)
        else:
          train_mpp_predictions.append(0)
        if i[1]>0.5:
          train_ml_predictions.append(1)
        else:
          train_ml_predictions.append(0)

      for i,j in zip(mpp_targets,ml_targets):
        real_train_mpp.append(i.cpu().item())
        real_train_ml.append(j.cpu().item())
    
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    model.eval()

    with torch.no_grad():
      for data in validation_loader:
    
        input_ids = data[0].to(device)
        attention_mask = data[1].to(device)
        token_type_ids = data[2].to(device)
      
        mpp_targets = data[3].to(device)
        ml_targets = data[4].to(device)
        first_targets = data[5].to(device)
        second_targets = data[6].to(device)
        first_sen_len = data[7].to(device)
        second_sen_len = data[8].to(device)
      

        output_cls,output_sen1,ouptut_sen2 = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids = token_type_ids,
        max_len = max_len,
        length1 = first_sen_len,
        length2 = second_sen_len
   
        )
        mpp_ml_label = torch.stack((mpp_targets,ml_targets),1)     
      
        loss1 = loss_cls(output_cls.view(-1),mpp_ml_label.view(-1)).to(device)
        
        loss2 = loss_reg(output_sen1,first_targets.view(-1))
        
        loss3 = loss_reg(ouptut_sen2,second_targets.view(-1))
        
        loss = loss1+10*loss2+10*loss3

        validation_loss.append(loss.item())
      
        for i in output_cls:
          if i[0]>0.5:
            validation_mpp_predictions.append(1)
          else:
            validation_mpp_predictions.append(0)
          if i[1]>0.5:
            validation_ml_predictions.append(1)
          else:
            validation_ml_predictions.append(0)

        for i,j in zip(mpp_targets,ml_targets):
          real_validation_mpp.append(i.cpu().item())
          real_validation_ml.append(j.cpu().item())
    
    train_mpp_accuracy = accuracy_score(real_train_mpp, train_mpp_predictions)
    train_ml_accuracy = accuracy_score(real_train_ml, train_ml_predictions)
    validation_mpp_accuracy = accuracy_score(real_validation_mpp, validation_mpp_predictions)
    validation_ml_accuracy = accuracy_score(real_validation_ml, validation_ml_predictions)
    
    final_train_loss = np.mean(train_loss)
 
    final_validation_loss = np.mean(validation_loss)

    average_accuracy = (validation_mpp_accuracy+validation_ml_accuracy)/2

    if average_accuracy > current_accuracy_state:
      current_accuracy_state =  average_accuracy
      torch.save(model.state_dict(), 'double_value_cls.bin')



    print(
'Epoch [{}] Train Totol Loss: {:.4f}, Train MPP Accuracy: {:.4f}, Train ML Accuracy: {:.4f}, Valid Total Loss: {:.4f}, Valid MPP Accuracy: {:.4f}, Valid ML Accuracy: {:.4f}'
    .format(epo+1,final_train_loss, train_mpp_accuracy, train_ml_accuracy,final_validation_loss,validation_mpp_accuracy,validation_ml_accuracy))

# %%
random_seed = [171,354,550,667,985]
for i in random_seed:
  
  df = shuffle(df,random_state=i)

  
  train = df[0:156]

  test = df[156:200]

  train_post1 = train['post1']
  train_post2 = train['post2']
  train_mpp_label = train['MPP_label']
  train_ml_label = train['ML_label']
  train_mpp_value1 = train['MPP1'] 
  train_mpp_value2 = train['MPP2']
  train_ml_value1 = train['ML1']
  train_ml_value2 = train['ML2']

  test_post1 = test['post1']
  test_post2 = test['post2']
  test_mpp_label = test['MPP_label']
  test_ml_label = test['ML_label']
  test_mpp_value1 = test['MPP1'] 
  test_mpp_value2 = test['MPP2']
  test_ml_value1 = test['ML1']
  test_ml_value2 = test['ML2']

  max_len = 256
  batch_size = 1
  train_dataloader = generate_dataloader(train_post1,train_post2,train_mpp_label,train_ml_label,max_len,train_mpp_value1,train_ml_value1,train_mpp_value2,train_ml_value2,batch_size)
  test_dataloader = generate_dataloader(test_post1,test_post2,test_mpp_label,test_ml_label,max_len,test_mpp_value1,test_ml_value1,test_mpp_value2,test_ml_value2,batch_size)

  label_num_cls = 2
  label_num_reg = 2
  model= BertNerClassifier(label_num_cls,label_num_reg).to(device)
  optimizer = AdamW(model.parameters(), lr=2e-6, correct_bias=False)
  
  
  train_and_eval(model, 
    train_dataloader, 
    test_dataloader, 
    optimizer,  
    device,
    EPOCHS,
    )
# Out:
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 1.0188, Train MPP Accuracy: 0.5256, Train ML Accuracy: 0.5064, Valid Total Loss: 0.8620, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.4750
# Epoch [2] Train Totol Loss: 0.8340, Train MPP Accuracy: 0.5833, Train ML Accuracy: 0.6410, Valid Total Loss: 0.8156, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.4250
# Epoch [3] Train Totol Loss: 0.6512, Train MPP Accuracy: 0.6795, Train ML Accuracy: 0.8269, Valid Total Loss: 0.8236, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.4500
# Epoch [4] Train Totol Loss: 0.5604, Train MPP Accuracy: 0.8141, Train ML Accuracy: 0.8910, Valid Total Loss: 0.8228, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4250
# Epoch [5] Train Totol Loss: 0.4635, Train MPP Accuracy: 0.9103, Train ML Accuracy: 0.9551, Valid Total Loss: 0.8566, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4250
# Epoch [6] Train Totol Loss: 0.3543, Train MPP Accuracy: 0.9744, Train ML Accuracy: 0.9679, Valid Total Loss: 0.8950, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.4250
# Epoch [7] Train Totol Loss: 0.2539, Train MPP Accuracy: 0.9936, Train ML Accuracy: 0.9744, Valid Total Loss: 0.9414, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4500
# Epoch [8] Train Totol Loss: 0.1798, Train MPP Accuracy: 1.0000, Train ML Accuracy: 0.9936, Valid Total Loss: 1.0009, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.4500
# Epoch [9] Train Totol Loss: 0.1305, Train MPP Accuracy: 1.0000, Train ML Accuracy: 0.9936, Valid Total Loss: 1.0381, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.4750
# Epoch [10] Train Totol Loss: 0.1062, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0748, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.4750
# Epoch [11] Train Totol Loss: 0.1013, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1160, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.4750
# Epoch [12] Train Totol Loss: 0.1180, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1212, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [13] Train Totol Loss: 0.1372, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1362, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.4750
# Epoch [14] Train Totol Loss: 0.1244, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1887, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [15] Train Totol Loss: 0.0980, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2227, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [16] Train Totol Loss: 0.0694, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1950, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [17] Train Totol Loss: 0.0510, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2552, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.4750
# Epoch [18] Train Totol Loss: 0.0420, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2682, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [19] Train Totol Loss: 0.0361, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2765, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [20] Train Totol Loss: 0.0314, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2888, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [21] Train Totol Loss: 0.0281, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3168, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [22] Train Totol Loss: 0.0261, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3601, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [23] Train Totol Loss: 0.0258, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4134, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [24] Train Totol Loss: 0.0269, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4588, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [25] Train Totol Loss: 0.0289, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4714, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [26] Train Totol Loss: 0.0328, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4625, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [27] Train Totol Loss: 0.0395, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4544, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [28] Train Totol Loss: 0.0514, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4796, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [29] Train Totol Loss: 0.0691, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5400, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [30] Train Totol Loss: 0.0800, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6108, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [31] Train Totol Loss: 0.0719, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5910, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.4750
# Epoch [32] Train Totol Loss: 0.0487, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5509, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [33] Train Totol Loss: 0.0316, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5831, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [34] Train Totol Loss: 0.0218, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6290, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [35] Train Totol Loss: 0.0155, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6726, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [36] Train Totol Loss: 0.0120, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7117, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [37] Train Totol Loss: 0.0095, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7591, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [38] Train Totol Loss: 0.0081, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7859, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [39] Train Totol Loss: 0.0074, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7731, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [40] Train Totol Loss: 0.0072, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7762, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [41] Train Totol Loss: 0.0076, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7826, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [42] Train Totol Loss: 0.0079, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8099, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [43] Train Totol Loss: 0.0099, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7969, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [44] Train Totol Loss: 0.0123, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8487, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [45] Train Totol Loss: 0.0147, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8004, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5750
# Epoch [46] Train Totol Loss: 0.0191, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6851, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [47] Train Totol Loss: 0.0187, Train MPP Accuracy: 1.0000, Train ML Accuracy: 0.9936, Valid Total Loss: 1.7797, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.5250
# Epoch [48] Train Totol Loss: 0.0164, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8305, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.5250
# Epoch [49] Train Totol Loss: 0.0224, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8126, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5250
# Epoch [50] Train Totol Loss: 0.0309, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7754, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5250
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 1.0548, Train MPP Accuracy: 0.4808, Train ML Accuracy: 0.4679, Valid Total Loss: 0.8540, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [2] Train Totol Loss: 0.9025, Train MPP Accuracy: 0.5897, Train ML Accuracy: 0.6154, Valid Total Loss: 0.8233, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [3] Train Totol Loss: 0.6773, Train MPP Accuracy: 0.6859, Train ML Accuracy: 0.7436, Valid Total Loss: 0.7812, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [4] Train Totol Loss: 0.6059, Train MPP Accuracy: 0.7692, Train ML Accuracy: 0.8269, Valid Total Loss: 0.7881, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5250
# Epoch [5] Train Totol Loss: 0.5233, Train MPP Accuracy: 0.8590, Train ML Accuracy: 0.8974, Valid Total Loss: 0.8044, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.5500
# Epoch [6] Train Totol Loss: 0.4268, Train MPP Accuracy: 0.9487, Train ML Accuracy: 0.9551, Valid Total Loss: 0.8069, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5000
# Epoch [7] Train Totol Loss: 0.3275, Train MPP Accuracy: 0.9679, Train ML Accuracy: 0.9936, Valid Total Loss: 0.8008, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [8] Train Totol Loss: 0.2404, Train MPP Accuracy: 0.9936, Train ML Accuracy: 1.0000, Valid Total Loss: 0.7911, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [9] Train Totol Loss: 0.1762, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8006, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.6000
# Epoch [10] Train Totol Loss: 0.1324, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.8452, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.6250
# Epoch [11] Train Totol Loss: 0.1074, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9149, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6000
# Epoch [12] Train Totol Loss: 0.0953, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9580, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6000
# Epoch [13] Train Totol Loss: 0.0937, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9422, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.6500
# Epoch [14] Train Totol Loss: 0.0974, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 0.9222, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.6000
# Epoch [15] Train Totol Loss: 0.1269, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0448, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.6250
# Epoch [16] Train Totol Loss: 0.1455, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0014, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6500
# Epoch [17] Train Totol Loss: 0.1392, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0288, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6500
# Epoch [18] Train Totol Loss: 0.1180, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0798, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.6000
# Epoch [19] Train Totol Loss: 0.0785, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0691, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6000
# Epoch [20] Train Totol Loss: 0.0505, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0585, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.6000
# Epoch [21] Train Totol Loss: 0.0326, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0610, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.6000
# Epoch [22] Train Totol Loss: 0.0228, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0679, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.6500
# Epoch [23] Train Totol Loss: 0.0178, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0797, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6500
# Epoch [24] Train Totol Loss: 0.0150, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0935, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6500
# Epoch [25] Train Totol Loss: 0.0134, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1104, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.6250
# Epoch [26] Train Totol Loss: 0.0124, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1274, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.6250
# Epoch [27] Train Totol Loss: 0.0118, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1500, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6500
# Epoch [28] Train Totol Loss: 0.0120, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1722, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6250
# Epoch [29] Train Totol Loss: 0.0134, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2019, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6000
# Epoch [30] Train Totol Loss: 0.0171, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2338, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5750
# Epoch [31] Train Totol Loss: 0.0219, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2473, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5750
# Epoch [32] Train Totol Loss: 0.0257, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2971, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5750
# Epoch [33] Train Totol Loss: 0.0265, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2979, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.6000
# Epoch [34] Train Totol Loss: 0.0283, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3140, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6000
# Epoch [35] Train Totol Loss: 0.0371, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3031, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6000
# Epoch [36] Train Totol Loss: 0.0531, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3404, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.6000
# Epoch [37] Train Totol Loss: 0.0868, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3365, Valid MPP Accuracy: 0.4750, Valid ML Accuracy: 0.5500
# Epoch [38] Train Totol Loss: 0.1093, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3873, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.6000
# Epoch [39] Train Totol Loss: 0.0833, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4383, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.6000
# Epoch [40] Train Totol Loss: 0.0489, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4064, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.6000
# Epoch [41] Train Totol Loss: 0.0301, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3680, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5750
# Epoch [42] Train Totol Loss: 0.0207, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4315, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5750
# Epoch [43] Train Totol Loss: 0.0155, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4552, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [44] Train Totol Loss: 0.0122, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4888, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [45] Train Totol Loss: 0.0099, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4973, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [46] Train Totol Loss: 0.0082, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5137, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [47] Train Totol Loss: 0.0071, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5208, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [48] Train Totol Loss: 0.0064, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5313, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [49] Train Totol Loss: 0.0062, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5429, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [50] Train Totol Loss: 0.0063, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5595, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 1.0543, Train MPP Accuracy: 0.4872, Train ML Accuracy: 0.5128, Valid Total Loss: 0.9086, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4750
# Epoch [2] Train Totol Loss: 0.8999, Train MPP Accuracy: 0.6090, Train ML Accuracy: 0.6346, Valid Total Loss: 0.8293, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4250
# Epoch [3] Train Totol Loss: 0.6724, Train MPP Accuracy: 0.6923, Train ML Accuracy: 0.7372, Valid Total Loss: 0.8217, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4500
# Epoch [4] Train Totol Loss: 0.5917, Train MPP Accuracy: 0.7564, Train ML Accuracy: 0.8462, Valid Total Loss: 0.8473, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5000
# Epoch [5] Train Totol Loss: 0.5109, Train MPP Accuracy: 0.8462, Train ML Accuracy: 0.9231, Valid Total Loss: 0.8814, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4500
# Epoch [6] Train Totol Loss: 0.4152, Train MPP Accuracy: 0.9423, Train ML Accuracy: 0.9551, Valid Total Loss: 0.9185, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4500
# Epoch [7] Train Totol Loss: 0.3135, Train MPP Accuracy: 0.9872, Train ML Accuracy: 0.9808, Valid Total Loss: 0.9722, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4250
# Epoch [8] Train Totol Loss: 0.2275, Train MPP Accuracy: 0.9872, Train ML Accuracy: 0.9936, Valid Total Loss: 1.0215, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4000
# Epoch [9] Train Totol Loss: 0.1639, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0733, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [10] Train Totol Loss: 0.1229, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1215, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4000
# Epoch [11] Train Totol Loss: 0.0995, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1850, Valid MPP Accuracy: 0.3000, Valid ML Accuracy: 0.3750
# Epoch [12] Train Totol Loss: 0.0912, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2260, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.3750
# Epoch [13] Train Totol Loss: 0.1047, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2844, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4250
# Epoch [14] Train Totol Loss: 0.1393, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3099, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4250
# Epoch [15] Train Totol Loss: 0.1640, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4166, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4000
# Epoch [16] Train Totol Loss: 0.1451, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5240, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4250
# Epoch [17] Train Totol Loss: 0.1308, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5084, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4250
# Epoch [18] Train Totol Loss: 0.0915, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6030, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3500
# Epoch [19] Train Totol Loss: 0.0651, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5995, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.3500
# Epoch [20] Train Totol Loss: 0.0481, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5725, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.3750
# Epoch [21] Train Totol Loss: 0.0382, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5673, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [22] Train Totol Loss: 0.0327, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5880, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.3750
# Epoch [23] Train Totol Loss: 0.0291, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6222, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.3750
# Epoch [24] Train Totol Loss: 0.0271, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6648, Valid MPP Accuracy: 0.3000, Valid ML Accuracy: 0.3500
# Epoch [25] Train Totol Loss: 0.0256, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7039, Valid MPP Accuracy: 0.3000, Valid ML Accuracy: 0.4000
# Epoch [26] Train Totol Loss: 0.0246, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7423, Valid MPP Accuracy: 0.3000, Valid ML Accuracy: 0.3750
# Epoch [27] Train Totol Loss: 0.0249, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7722, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [28] Train Totol Loss: 0.0249, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8050, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4000
# Epoch [29] Train Totol Loss: 0.0269, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8405, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4000
# Epoch [30] Train Totol Loss: 0.0297, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8821, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4000
# Epoch [31] Train Totol Loss: 0.0333, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9489, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4000
# Epoch [32] Train Totol Loss: 0.0433, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9543, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4000
# Epoch [33] Train Totol Loss: 0.0615, Train MPP Accuracy: 1.0000, Train ML Accuracy: 0.9936, Valid Total Loss: 1.8387, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4500
# Epoch [34] Train Totol Loss: 0.0728, Train MPP Accuracy: 0.9936, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7886, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4250
# Epoch [35] Train Totol Loss: 0.0867, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9405, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4500
# Epoch [36] Train Totol Loss: 0.0967, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0699, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4750
# Epoch [37] Train Totol Loss: 0.1029, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8614, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4500
# Epoch [38] Train Totol Loss: 0.0862, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8068, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4750
# Epoch [39] Train Totol Loss: 0.0605, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8777, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4500
# Epoch [40] Train Totol Loss: 0.0411, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9295, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4750
# Epoch [41] Train Totol Loss: 0.0292, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9747, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4750
# Epoch [42] Train Totol Loss: 0.0218, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0222, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4750
# Epoch [43] Train Totol Loss: 0.0169, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0690, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4750
# Epoch [44] Train Totol Loss: 0.0134, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1167, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.4750
# Epoch [45] Train Totol Loss: 0.0108, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1608, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4500
# Epoch [46] Train Totol Loss: 0.0088, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2036, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4500
# Epoch [47] Train Totol Loss: 0.0074, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2443, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.4500
# Epoch [48] Train Totol Loss: 0.0063, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2805, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4500
# Epoch [49] Train Totol Loss: 0.0056, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3200, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4500
# Epoch [50] Train Totol Loss: 0.0050, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.3447, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.4500
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 1.0717, Train MPP Accuracy: 0.5577, Train ML Accuracy: 0.5321, Valid Total Loss: 0.8733, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5500
# Epoch [2] Train Totol Loss: 0.8620, Train MPP Accuracy: 0.6282, Train ML Accuracy: 0.5897, Valid Total Loss: 0.8452, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5250
# Epoch [3] Train Totol Loss: 0.6702, Train MPP Accuracy: 0.7051, Train ML Accuracy: 0.7179, Valid Total Loss: 0.8273, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5250
# Epoch [4] Train Totol Loss: 0.5879, Train MPP Accuracy: 0.8013, Train ML Accuracy: 0.8205, Valid Total Loss: 0.8476, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.4250
# Epoch [5] Train Totol Loss: 0.4937, Train MPP Accuracy: 0.8974, Train ML Accuracy: 0.8846, Valid Total Loss: 0.8854, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.4250
# Epoch [6] Train Totol Loss: 0.3876, Train MPP Accuracy: 0.9679, Train ML Accuracy: 0.9615, Valid Total Loss: 0.9031, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.4750
# Epoch [7] Train Totol Loss: 0.2832, Train MPP Accuracy: 0.9872, Train ML Accuracy: 0.9679, Valid Total Loss: 0.9085, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.4500
# Epoch [8] Train Totol Loss: 0.2000, Train MPP Accuracy: 0.9936, Train ML Accuracy: 0.9936, Valid Total Loss: 0.9874, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [9] Train Totol Loss: 0.1481, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0766, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.4750
# Epoch [10] Train Totol Loss: 0.1311, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0845, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [11] Train Totol Loss: 0.1350, Train MPP Accuracy: 0.9936, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0441, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [12] Train Totol Loss: 0.1402, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1338, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [13] Train Totol Loss: 0.1302, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1357, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5250
# Epoch [14] Train Totol Loss: 0.1009, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1409, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [15] Train Totol Loss: 0.0780, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2242, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5250
# Epoch [16] Train Totol Loss: 0.0616, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3266, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5000
# Epoch [17] Train Totol Loss: 0.0588, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2556, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [18] Train Totol Loss: 0.0550, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2738, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5750
# Epoch [19] Train Totol Loss: 0.0507, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3138, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [20] Train Totol Loss: 0.0517, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3650, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [21] Train Totol Loss: 0.0494, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3424, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [22] Train Totol Loss: 0.0473, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3481, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [23] Train Totol Loss: 0.0493, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3628, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [24] Train Totol Loss: 0.0492, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4490, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5250
# Epoch [25] Train Totol Loss: 0.0467, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5535, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5250
# Epoch [26] Train Totol Loss: 0.0469, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5369, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5000
# Epoch [27] Train Totol Loss: 0.0459, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4960, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [28] Train Totol Loss: 0.0395, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5222, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [29] Train Totol Loss: 0.0307, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5646, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5250
# Epoch [30] Train Totol Loss: 0.0262, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5966, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [31] Train Totol Loss: 0.0228, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5770, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5250
# Epoch [32] Train Totol Loss: 0.0238, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6161, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5250
# Epoch [33] Train Totol Loss: 0.0242, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5783, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [34] Train Totol Loss: 0.0252, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6219, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5000
# Epoch [35] Train Totol Loss: 0.0303, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6400, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5000
# Epoch [36] Train Totol Loss: 0.0425, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6431, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5000
# Epoch [37] Train Totol Loss: 0.0567, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7281, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [38] Train Totol Loss: 0.0642, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7374, Valid MPP Accuracy: 0.5750, Valid ML Accuracy: 0.5000
# Epoch [39] Train Totol Loss: 0.0667, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6618, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5500
# Epoch [40] Train Totol Loss: 0.0502, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7344, Valid MPP Accuracy: 0.5500, Valid ML Accuracy: 0.5750
# Epoch [41] Train Totol Loss: 0.0317, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7848, Valid MPP Accuracy: 0.6000, Valid ML Accuracy: 0.5000
# Epoch [42] Train Totol Loss: 0.0215, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8595, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5250
# Epoch [43] Train Totol Loss: 0.0167, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8079, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5500
# Epoch [44] Train Totol Loss: 0.0139, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8008, Valid MPP Accuracy: 0.5000, Valid ML Accuracy: 0.5750
# Epoch [45] Train Totol Loss: 0.0122, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8041, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5750
# Epoch [46] Train Totol Loss: 0.0108, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8169, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5750
# Epoch [47] Train Totol Loss: 0.0099, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8377, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5750
# Epoch [48] Train Totol Loss: 0.0094, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8732, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5750
# Epoch [49] Train Totol Loss: 0.0095, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9102, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5750
# Epoch [50] Train Totol Loss: 0.0100, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9567, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.5750
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch [1] Train Totol Loss: 1.1110, Train MPP Accuracy: 0.4744, Train ML Accuracy: 0.5064, Valid Total Loss: 1.0169, Valid MPP Accuracy: 0.3000, Valid ML Accuracy: 0.5500
# Epoch [2] Train Totol Loss: 0.8801, Train MPP Accuracy: 0.5897, Train ML Accuracy: 0.6090, Valid Total Loss: 0.8987, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.5250
# Epoch [3] Train Totol Loss: 0.6767, Train MPP Accuracy: 0.7500, Train ML Accuracy: 0.7372, Valid Total Loss: 0.8631, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.5750
# Epoch [4] Train Totol Loss: 0.5787, Train MPP Accuracy: 0.8590, Train ML Accuracy: 0.8397, Valid Total Loss: 0.8805, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.5250
# Epoch [5] Train Totol Loss: 0.4795, Train MPP Accuracy: 0.9744, Train ML Accuracy: 0.9359, Valid Total Loss: 0.9131, Valid MPP Accuracy: 0.3000, Valid ML Accuracy: 0.5250
# Epoch [6] Train Totol Loss: 0.3713, Train MPP Accuracy: 0.9936, Train ML Accuracy: 0.9615, Valid Total Loss: 0.9499, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4750
# Epoch [7] Train Totol Loss: 0.2679, Train MPP Accuracy: 0.9936, Train ML Accuracy: 0.9808, Valid Total Loss: 0.9945, Valid MPP Accuracy: 0.2500, Valid ML Accuracy: 0.4250
# Epoch [8] Train Totol Loss: 0.1876, Train MPP Accuracy: 0.9936, Train ML Accuracy: 0.9936, Valid Total Loss: 1.0381, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.4500
# Epoch [9] Train Totol Loss: 0.1333, Train MPP Accuracy: 0.9936, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0692, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.5000
# Epoch [10] Train Totol Loss: 0.0993, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.0955, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.5000
# Epoch [11] Train Totol Loss: 0.0800, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1178, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5250
# Epoch [12] Train Totol Loss: 0.0705, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1483, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.5500
# Epoch [13] Train Totol Loss: 0.0734, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.1877, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5500
# Epoch [14] Train Totol Loss: 0.0844, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2908, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4750
# Epoch [15] Train Totol Loss: 0.1152, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2408, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.4500
# Epoch [16] Train Totol Loss: 0.1765, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5976, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.4500
# Epoch [17] Train Totol Loss: 0.1792, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4862, Valid MPP Accuracy: 0.4250, Valid ML Accuracy: 0.5250
# Epoch [18] Train Totol Loss: 0.1295, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.2824, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5500
# Epoch [19] Train Totol Loss: 0.0702, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3213, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5250
# Epoch [20] Train Totol Loss: 0.0432, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3525, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.5250
# Epoch [21] Train Totol Loss: 0.0300, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.3700, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5500
# Epoch [22] Train Totol Loss: 0.0233, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4014, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.6000
# Epoch [23] Train Totol Loss: 0.0188, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4273, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.6000
# Epoch [24] Train Totol Loss: 0.0161, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4639, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.6000
# Epoch [25] Train Totol Loss: 0.0142, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.4910, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.6000
# Epoch [26] Train Totol Loss: 0.0130, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5268, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.6000
# Epoch [27] Train Totol Loss: 0.0126, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5501, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.6000
# Epoch [28] Train Totol Loss: 0.0126, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.5836, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.6000
# Epoch [29] Train Totol Loss: 0.0141, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6045, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.6000
# Epoch [30] Train Totol Loss: 0.0153, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6376, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.6000
# Epoch [31] Train Totol Loss: 0.0186, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6623, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5750
# Epoch [32] Train Totol Loss: 0.0200, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6968, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5500
# Epoch [33] Train Totol Loss: 0.0266, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6852, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5500
# Epoch [34] Train Totol Loss: 0.0337, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6152, Valid MPP Accuracy: 0.4500, Valid ML Accuracy: 0.5750
# Epoch [35] Train Totol Loss: 0.0468, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7436, Valid MPP Accuracy: 0.4000, Valid ML Accuracy: 0.5500
# Epoch [36] Train Totol Loss: 0.0726, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8471, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5000
# Epoch [37] Train Totol Loss: 0.1035, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.6300, Valid MPP Accuracy: 0.5250, Valid ML Accuracy: 0.4500
# Epoch [38] Train Totol Loss: 0.0852, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7823, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.5000
# Epoch [39] Train Totol Loss: 0.0449, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8098, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.5250
# Epoch [40] Train Totol Loss: 0.0307, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.7851, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.5250
# Epoch [41] Train Totol Loss: 0.0255, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8234, Valid MPP Accuracy: 0.3750, Valid ML Accuracy: 0.5250
# Epoch [42] Train Totol Loss: 0.0229, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.8907, Valid MPP Accuracy: 0.3500, Valid ML Accuracy: 0.5250
# Epoch [43] Train Totol Loss: 0.0209, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 1.9651, Valid MPP Accuracy: 0.3250, Valid ML Accuracy: 0.5250
# Epoch [44] Train Totol Loss: 0.0192, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.0370, Valid MPP Accuracy: 0.2500, Valid ML Accuracy: 0.5250
# Epoch [45] Train Totol Loss: 0.0177, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1004, Valid MPP Accuracy: 0.2500, Valid ML Accuracy: 0.5250
# Epoch [46] Train Totol Loss: 0.0167, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.1547, Valid MPP Accuracy: 0.2500, Valid ML Accuracy: 0.5250
# Epoch [47] Train Totol Loss: 0.0159, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2021, Valid MPP Accuracy: 0.2500, Valid ML Accuracy: 0.5000
# Epoch [48] Train Totol Loss: 0.0154, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2374, Valid MPP Accuracy: 0.2250, Valid ML Accuracy: 0.5000
# Epoch [49] Train Totol Loss: 0.0151, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2512, Valid MPP Accuracy: 0.2250, Valid ML Accuracy: 0.5000
# Epoch [50] Train Totol Loss: 0.0150, Train MPP Accuracy: 1.0000, Train ML Accuracy: 1.0000, Valid Total Loss: 2.2328, Valid MPP Accuracy: 0.2750, Valid ML Accuracy: 0.5000

# %%
model.load_state_dict(torch.load('double_value_cls.bin', map_location=torch.device("cuda:0")))
# Out:
# <All keys matched successfully>

# %%
def generate_test_data(post1,post2,max_len):
 
  full_text = []
  attention_mask = []
  token_type_ids = []
  first_length = []
  second_length = []
  for i,j in zip(post1,post2):
    if len(i)>max_len:
      i = i[:max_len]
    if len(j)>max_len:
      j = j[:max_len]
    
    i = tokenizer.tokenize(i)
    j = tokenizer.tokenize(j)

    first_length.append(len(i))
    second_length.append(len(j))
    
    text = ['[CLS]']+i+['[SEP]']+j+['[SEP]']
    full_text.append(tokenizer.convert_tokens_to_ids(text))
    attention_mask.append(np.ones_like(text))

    token_type_id = [0]*(len(i)+2) + [1]*(len(j)+1)
    token_type_ids.append(token_type_id)

  all_pad_tokens = pad_sequences(full_text, maxlen=max_len*2, padding='post', truncating='post')
  all_mask = pad_sequences(attention_mask, maxlen=max_len*2, padding='post', truncating='post')
  token_type_ids = pad_sequences(token_type_ids, maxlen=max_len*2, padding='post', truncating='post')
  
  return {
      'input_ids': torch.tensor(all_pad_tokens,dtype=torch.long),
      'attention_mask': torch.tensor(all_mask, dtype=torch.long),
      'token_type_ids':torch.tensor(token_type_ids,dtype = torch.long),
      'first_sen_len':torch.tensor(first_length,dtype = torch.long),
      'second_sen_len':torch.tensor(second_length,dtype = torch.long)
      
  }

# %%
 
class testSequence(Dataset):

    def __init__(self, data):

      self.features = data['input_ids']
      self.mask = data['attention_mask']
      self.token_type_ids = data['token_type_ids']
      self.first_sen_len = data['first_sen_len']   
      self.second_sen_len = data['second_sen_len']   

    def __len__(self):

        return len(self.features)

    def __getitem__(self, index):

        return self.features[index],self.mask[index],self.token_type_ids[index],self.first_sen_len[index],self.second_sen_len[index]

# %%
def generate_test_dataloader(post1,post2,max_len,batch_size):
  data = generate_test_data(post1,post2,max_len)
  data = testSequence(data)
  dataloader = DataLoader(data, num_workers=10, batch_size=batch_size)
  
  return dataloader

# %%
test_post1 = df2['post1']
test_post2 = df2['post2']
test_loader = generate_test_dataloader(test_post1,test_post2,256,8)

# %%
def real_prediction(model, 
  test_dataloader,  
  optimizer,
  device
  ):
  
  test_mpp_predictions = []
  test_ml_predictions = []
  
  model.eval()
  with torch.no_grad():
    for data in test_dataloader:
    
        input_ids = data[0].to(device)
        attention_mask = data[1].to(device)
        token_type_ids = data[2].to(device)
      
        
        first_sen_len = data[3].to(device)
        second_sen_len = data[4].to(device)
      

        output_cls,output_sen1,ouptut_sen2 = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        token_type_ids = token_type_ids,
        max_len = max_len,
        length1 = first_sen_len,
        length2 = second_sen_len
   
        )
     
        
      
        for i in output_cls:
          if i[0]>0.5:
            test_mpp_predictions.append(1)
          else:
            test_mpp_predictions.append(0)
          if i[1]>0.5:
            test_ml_predictions.append(1)
          else:
            test_ml_predictions.append(0)
        
  return test_mpp_predictions,test_ml_predictions

# %%
test_mpp_predictions,test_ml_predictions = real_prediction(model,test_loader,optimizer,device)

# %%
df2['MPP_prediction'] = test_mpp_predictions
df2['ML_prediction'] = test_ml_predictions
df2.to_json('ERAI_pairwise_[aiml]_[1].json')
